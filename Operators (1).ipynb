# %%
18+5
# Out:
# 23

# %%
6*6
# Out:
# 36

# %%
36/25
# Out:
# 1.44

# %%
10%2
# Out:
# 0

# %%
10 % 3
# Out:
# 1

# %%
'hello'+'pyhton'
# Out:
# 'hellopyhton'

# %%
'hello'*3
# Out:
# 'hellohellohello'

# %%
'today'+' '+'is holiday'
# Out:
# 'today is holiday'

# %%
' today ' + ' is holiday'
# Out:
# ' today  is holiday'

# %% [raw]
# # Vairable :- Vraiable is used to store data set
#
# Rules :-
# 5= 2 / @= 5 / Cannot perform operation
# @, only number / cannot perform operations
# a= 5 / is simple character
# We can assign any character with number
# a5 = 10 Is possible
# a_7 = 100 is possible

# %%
A=10
B=5 
A+B
# Out:
# 15

# %%
A
# Out:
# 10

# %%
B
# Out:
# 5

# %%
type(A)
# Out:
# int

# %%
name = 'akash'

# %%
type(name)
# Out:
# str

# %%
name *5
# Out:
# 'akashakashakashakashakash'

# %%
'My Name is ' + name
# Out:
# 'My Name is akash'

# %%
'My name is ' + name + '. Today i am going to pune'
# Out:
# 'My name is akash. Today i am going to pune'

# %% [raw]
# # How to typecasting  :- Changing data type

# %%
a = '15'

# %%
type(a)
# Out:
# str

# %%
int('15')
# Out:
# 15

# %%
d='hello'

# %%
int(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 int(d)
#
# NameError: name 'd' is not defined

# %%
float(5)
# Out:
# 5.0

# %%
float(0.45)
# Out:
# 0.45

# %% [raw]
# # Operators ------>operate----> Control

# %% [raw]
# #1. Comparsion operators :- compare two data types and gives the output in true or false
#
# ' Greater then equal to'  >=
# ' Less then equal to'    <=
# '5!= 10' = not equal to
#  ' == ' compare Two data set  values

# %%
5<7
# Out:
# True

# %%
10<8
# Out:
# False

# %%
10 == 10
# Out:
# True

# %%
5 == 10
# Out:
# False

# %%
5!=10
# Out:
# True

# %%
10>10
# Out:
# False

# %%
10>= 10
# Out:
# True

# %%
5<=10
# Out:
# True

# %%
5<5
# Out:
# False

# %%
5<=5
# Out:
# True

# %%
10==5
# Out:
# False

# %%
10!= 5
# Out:
# True

# %%
'Hello' == 'Hello'
# Out:
# True

# %%
'Hello' == ' hello'
# Out:
# False

# %%
'Hello'!= 'Python'
# Out:
# True

# %%
'hello'!= 'hello'
# Out:
# False

# %% [raw]
# # 2. Arthmetic opertions :-
#  +
#  -
#  /
#  *
#  %

# %% [raw]
# # 3. Logical opertors
#
#     1 .  or operator :- we need atleast one conditon to be true
#                   True or True --> True
#                    True or false --> True
#                    False or true ---> True
#                    False or false ---> False
#
#    2. And Opeator :- We need both condtion true
#                     True & true --> True
#                     True & False --> False
#                     False & true --> False
#                     False & false --> False
#
#   3.Not Opeator :-
#                     Not True --> False
#                     Not false --> True

# %%
True or True
# Out:
# True

# %%
False & False
# Out:
# False

# %%
False & True
# Out:
# False

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
True or False and False or True
# Out:
# True

# %%
name = ' Akash '

# %%
name *3
# Out:
# ' Akash  Akash  Akash '

# %% [raw]
# # How to take user input

# %%
Name = input('Write Your Name')
# Out:
# Write Your Name Akash Patil

# %%
Name
# Out:
# 'Akash Patil'

# %%
city = input('Write your city name')
# Out:
# Write your city name Solapur

# %%
city
# Out:
# 'Solapur'

# %%
'Your city name is ' + city
# Out:
# 'Your city name is Solapur'

# %%
print(f'your city name is {city}') #F format is nothing / b ut replacing the varaibvle in curly brackets
# Out:
# your city name is Solapur

# %%
print(f'Your name is {Name}')
# Out:
# Your name is Akash Patil

# %%
('Your city name is' , 'Solapur')
# Out:
# ('Your city name is', 'Solapur')

# %%
color = input('write your fav color name')
# Out:
# write your fav color name Black

# %%
color
# Out:
# 'Black'

# %%
print(f'Your fav color is {color} amd  city name is {city}')
# Out:
# Your fav color is Black amd  city name is Solapur

# %%
first_name = input('Write your first name')
Last_name= input('write your last name' )
print(f'Your first name is {first_name} and your last name is {Last_name}')
# Out:
# Write your first name akash
# write your last name patil
# Your first name is akash and your last name is patil

# %%
type(first_name)
# Out:
# str

# %%
age = input('write your age')
# Out:
# write your age 45

# %%
age
# Out:
# '45'

# %%
type(age)
# Out:
# str

# %%
age=int(input('write your age'))
# Out:
# write your age 65

# %%
age
# Out:
# 65

# %%
type(age)
# Out:
# int

# %%
age=int(input('write your age'))
print(f'your age is {age}')
# Out:
# write your age 55
# your age is 55

# %%
'Your age is ',age
# Out:
# ('Your age is ', 55)

# %%
height = float(input('Write your height'))
# Out:
# Write your height 6.5

# %%
height
# Out:
# 6.5

# %%
type(height)
# Out:
# float

# %%
height = float(input('Write your height'))
print(f'your height is {height}')
# Out:
# Write your height 5.5
# your height is 5.5

# %%
a = int(input( ' write value for a'))
b = int(input('write value for b'))
c = a + b
# Out:
#  write value for a 5
# write value for b 10

# %%
c
# Out:
# 15

# %%
car = input()
# Out:
#  nexon

# %%
car
# Out:
# 'nexon'

# %%
weight = float(input('write your weight'))
# Out:
# write your weight 55.5

# %%
weight
# Out:
# 55.5

# %%
type(weight)
# Out:
# float

# %%
type(car)
# Out:
# str

# %%
first_name = 'Sneha' 
last_name = 'Patil' 
full_name = first_name +" " + last_name  # ADD space between the first and last name 
print(full_name)
# Out:
# Sneha Patil

# %%
3 * 'hello'
# Out:
# 'hellohellohello'

# %%
num = 5

# %%
num_as_string = str(num)

# %%
type(num)
# Out:
# int
