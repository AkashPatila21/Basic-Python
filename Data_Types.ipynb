# %%
10+5
# Out:
# 15

# %%
print(10+5)
# Out:
# 15

# %% [markdown]
# # Data Types in Python

# %% [markdown]
# Today we are going to learn the data types in Python

# %% [raw]
# #6----->u67..
# 6---->jdbg
# js
# ksaf

# %%
print(10+5) #i am doing addition of two dstsset
# Out:
# 15

# %%
#Below i am going to start coding 
print(12 + 5)
# Out:
# 17

# %% [raw]
# # 1. Integer --> Complete number is Int data
#
#      Eg:- 1. How many members are there in your family ?
#      ---> 4, 5,6
#
#           2. How many bank account you have ?
#        ----> 5,5,4,5
#
# How to identify the data type ?
# ->type()

# %%
type(5)
# Out:
# int

# %% [raw]
# # 2. Float --> Numbers in decimal format
#
#    Eg :- 1. What is your height in Feet/ cm ?
#       ---> 4.5 , 6.1
#
#          2.  What is your weight ?
#           --->45.5, 50.6

# %%
34.400
# Out:
# 34.4

# %%
type(34.400)
# Out:
# float

# %% [raw]
# # 3. Complex Numbers ---> vector values / vector plotting by using real axix using imgainary axis
#
#      Eg :- 1. 5+3j
#         -->(5+3j)

# %%
5+3j
# Out:
# (5+3j)

# %%
type(5+3j)
# Out:
# complex

# %% [raw]
# # 4. String --->  Writing downs the Names Alphabets , Sentences , Letters
#
#     *Single Line string ---> ' sentence ' , " Sentence / Name " --> Single quote & double Quotes
#     *Multiple line string ---> """ Sentence / Name """    ---> Triple qoutes

# %%
"today we are learning data types "
# Out:
# 'today we are learning data types '

# %%
print("today we are learning data types ")
# Out:
# today we are learning data types

# %%
""" This is My line no one. 
this is my line no Two.
This is my line no  three """
# Out:
# ' This is My line no one. \nthis is my line no Two.\nThis is my line no  three '

# %%
print(""" This is My line no one.
This is my line no Two.
This is my line no  three """)
# Out:
#  This is My line no one.
# This is my line no Two.
# This is my line no  three

# %%
type("Akash")
# Out:
# str

# %% [raw]
# #5. Boolean ---> Its is nothing but True or false output

# %%
15>9
# Out:
# True

# %%
16<6
# Out:
# False

# %%
type(15>6)
# Out:
# bool

# %%
5+'Hello'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 5+'Hello'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
'hello'+ 'Python'
# Out:
# 'helloPython'

# %% [raw]
#  Eg :-
#  1. 5+'Hello'
# --> No we cannot perform the operations between int & str
#
#  2 5+3.5
# --> Yes int & float can perform
#
# 3. Number + String ?
# --->Not possible

# %%
5+3.5
# Out:
# 8.5
